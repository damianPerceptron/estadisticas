# %% [markdown]
# # Distribución de Bernoulli

# %% [markdown]
# 1. Modelo para representar una **variable aleatoria discreta**, la cual solo puede tener dos sucesos posibles: exito o fracaso.
#
# 2. Estos sucesos son **mutuamente excluyentes**.
#
# 3. Se realiza un solo experimento (n=1)
#
# 4. El fracaso (no éxito) ***no es lo contrario de exito, sino a cualquier caso distinto a exito***, siempre y cuando haya más de dos probabilidades.

# %% [markdown]
# * Exito (p) = P(X=1)
# * Fracaso (q) = P(X=0) = 1 - p

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejemplos teóricos:

# %% [markdown]
# 1. lanzamiento de moneda (se efectúa una vez, 1/2)
# 2. lancamiento de un datos (se efectúa una vez, 1/6)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ejemplo más elaborado:

# %% [markdown]
# Carrera de ciclistas: apostamos a un corredor. Pero son 10 corredores
#
# Existe un sólo éxito posible: que gane nuestro corredor. Pero el fracaso (no éxito), en este caso, es más amplio.
#
# **P(X=1) = 1/10**
#
# Es decir: **P = casos probables / casos posibles** (regla de Laplace)

# %% [markdown]
# # Código:

# %%
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## <font color='red'>ciclista:</font>

# %% [markdown]
# 1. manualmente:

# %%
k = 1
m = 10
p = (k/m)**k * (m-1/m)**(k-1)
print("exito: ", p)
print("fracaso: ", 1-p)
# Out:
# exito:  0.1
# fracaso:  0.9

# %% [markdown]
# 2. con scypy

# %%
# ingreso
n = 1 #nuestra apuesta
p = 1/10 #probable/posible
loc=0

# PROCEDIMIENTO
k = np.arange(loc-1, n+1)
px = bernoulli.pmf(k, p, loc)

# SALIDA
print('k: ', k)
print('p(k):', px)
plt.title('bernoulli rango hasta n='+str(n))
plt.stem(k,px,use_line_collection=True)
plt.margins(0.1)
plt.show()
# Out:
# k:  [-1  0  1]
# p(k): [0.  0.9 0.1]

# %%
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
print("valor de p: ", p)
print("mean: ", mean)
print("variance: ", var)
print("skew: ", skew)
print("kurtosis: ", kurt)
# Out:
# valor de p:  0.1
# mean:  0.1
# variance:  0.09000000000000001
# skew:  2.6666666666666665
# kurtosis:  5.111111111111111

# %% [markdown]
# ## <font color='red'>dados:</font>

# %% [markdown]
# 1. manualmente

# %%
k = 1 #exito
m = 6 #muestra
p = (k/m)**k * (m-1/m)**(k-1)
print("exito: ", p)
print("fracaso: ", 1-p)
# Out:
# exito:  0.16666666666666666
# fracaso:  0.8333333333333334

# %% [markdown]
# 2. con scipy

# %%
# ingreso
n = 1 #nuestra apuesta
p = 1/6 #probable/posible
loc=0

# PROCEDIMIENTO
k = np.arange(loc-1, n+1)
px = bernoulli.pmf(k, p, loc)

# SALIDA
print('k: ', k)
print('p(k):', px)
plt.title('bernoulli rango hasta n='+str(n))
plt.stem(k,px,use_line_collection=True)
plt.margins(0.1)
plt.show()
# Out:
# k:  [-1  0  1]
# p(k): [0.         0.83333333 0.16666667]

# %%
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
print("valor de p: ", p)
print("mean: ", mean)
print("variance: ", var)
print("skew: ", skew)
print("kurtosis: ", kurt)
# Out:
# valor de p:  0.16666666666666666
# mean:  0.16666666666666666
# variance:  0.1388888888888889
# skew:  1.7888543819998322
# kurtosis:  1.2000000000000002

# %% [markdown]
# ## moneda

# %% [markdown]
# 1. manualmente

# %%
k = 1 #exito
m = 2 #muestra
p = (k/m)**k * (m-1/m)**(k-1)
print("exito: ", p)
print("fracaso: ", 1-p)
# Out:
# exito:  0.5
# fracaso:  0.5

# %%
# ingreso
n = 1 #nuestra apuesta
p = 1/2 #probable/posible
loc=0

# PROCEDIMIENTO
k = np.arange(loc-1, n+1)
px = bernoulli.pmf(k, p, loc)

# SALIDA
print('k: ', k)
print('p(k):', px)
plt.title('bernoulli rango hasta n='+str(n))
plt.stem(k,px,use_line_collection=True)
plt.margins(0.1)
plt.show()
# Out:
# k:  [-1  0  1]
# p(k): [0.  0.5 0.5]

# %%
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
print("valor de p: ", p)
print("mean: ", mean)
print("variance: ", var)
print("skew: ", skew)
print("kurtosis: ", kurt)
# Out:
# valor de p:  0.5
# mean:  0.5
# variance:  0.25
# skew:  0.0
# kurtosis:  -2.0

# %%
# ingreso
n = 1 #nuestra apuesta
p = 1/6 #probable/posible
loc=0

# PROCEDIMIENTO
k = np.arange(loc-1, n+1)
px = bernoulli.pmf(k, p, loc)

# SALIDA
print('k: ', k)
print('p(k):', px)
plt.title('bernoulli rango hasta n='+str(n))
plt.stem(k,px,use_line_collection=True)
plt.margins(0.1)
plt.show()
# Out:
# k:  [-1  0  1]
# p(k): [0.         0.83333333 0.16666667]
